# %%
#import libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
! pip install gdown
! gdown "https://drive.google.com/uc?export=download&id=1PAb8TZhyo92KheewWvhoVkPJapKPyfM7"
! gdown "https://drive.google.com/uc?export=download&id=1tnplgfTFKR61QrfwHluLHyE6I5Uegl-d"
! gdown "https://drive.google.com/uc?export=download&id=1QohpJwbUCJh-fAb0ubZjzNLk3vIcycyX"
! gdown "https://drive.google.com/uc?export=download&id=1CP7LhhRS0XIALEiUk_VuCHPWg6z0uYs9"
! gdown "https://drive.google.com/uc?export=download&id=1Dk9ENdYGtNnJZwu25MBHUckiLm2SlD1I"
! gdown "https://drive.google.com/uc?export=download&id=19hve9QvmbE3J_UwrWVHqvihJ7T3BHIgH"
! gdown "https://drive.google.com/uc?export=download&id=1VIAHSvFTTtUOOlOYrT2o1RN_m0Rf0UcG"
! gdown "https://drive.google.com/uc?export=download&id=1Gw5-3ciXlWr5fPBT2SQw8pxTmYEUOWCy"
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1PAb8TZhyo92KheewWvhoVkPJapKPyfM7
# To: /content/CEATLTD.NS.csv
# 100% 93.9k/93.9k [00:00<00:00, 35.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1tnplgfTFKR61QrfwHluLHyE6I5Uegl-d
# To: /content/COST.csv
# 100% 93.2k/93.2k [00:00<00:00, 82.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1QohpJwbUCJh-fAb0ubZjzNLk3vIcycyX
# To: /content/DFS.csv
# 100% 86.9k/86.9k [00:00<00:00, 32.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1CP7LhhRS0XIALEiUk_VuCHPWg6z0uYs9
# To: /content/MA.csv
# 100% 91.7k/91.7k [00:00<00:00, 82.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1Dk9ENdYGtNnJZwu25MBHUckiLm2SlD1I
# To: /content/MRF.NS.csv
# 100% 99.9k/99.9k [00:00<00:00, 87.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=19hve9QvmbE3J_UwrWVHqvihJ7T3BHIgH
# To: /content/PFE.csv
# ...

# %%
#import source files.

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-444946bf-7cc9-45af-8515-91b878f12958" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-444946bf-7cc9-45af-8515-91b878f12958">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#Read the source files.

d1 = pd.read_csv("UNH.csv") #d1 and d2 (Health)
d2=pd.read_csv("PFE.csv")
d3=pd.read_csv("DFS.csv")# d3 and d4(Banking)
d4=pd.read_csv("MA.csv")
d5=pd.read_csv("CEATLTD.NS.csv") #d5 and d6 (Manufacturing)
d6=pd.read_csv("MRF.NS.csv")
d7=pd.read_csv("WMT.csv")#d7 and d8 (Retail)
d8=pd.read_csv("COST.csv")

# %%
# Check top 5 rows of the banking dataset.

d1.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2015-07-08  119.050003  119.989998  ...  118.779999  109.685631  4009800
# 1  2015-07-09  120.040001  120.559998  ...  119.339996  110.202759  3315600
# 2  2015-07-10  120.989998  122.750000  ...  122.150002  112.797638  4033500
# 3  2015-07-13  123.099998  123.750000  ...  122.449997  113.074661  3766900
# 4  2015-07-14  122.180000  125.199997  ...  125.000000  115.429413  4192400
#
# [5 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
d1['scaled_close'] = scaler.fit_transform(d1['Close'].values.reshape(-1,1))
d2['scaled_close'] = scaler.fit_transform(d2['Close'].values.reshape(-1,1))
d3['scaled_close'] = scaler.fit_transform(d3['Close'].values.reshape(-1,1))
d4['scaled_close'] = scaler.fit_transform(d4['Close'].values.reshape(-1,1))
d5['scaled_close'] = scaler.fit_transform(d5['Close'].values.reshape(-1,1))
d6['scaled_close'] = scaler.fit_transform(d6['Close'].values.reshape(-1,1))
d7['scaled_close'] = scaler.fit_transform(d7['Close'].values.reshape(-1,1))
d8['scaled_close'] = scaler.fit_transform(d8['Close'].values.reshape(-1,1))

# %%
plt.figure(figsize=(10,5))
sns.set(style='darkgrid')
plt.title('close value in d1 vs. Close value in d2', fontsize = 15)
plt.xlabel('Dates' )
plt.ylabel('close value')


plt.plot( 'Date', 'scaled_close', data=d1, marker='o', color='olive', linewidth=2)
plt.plot( 'Date', 'scaled_close', data=d2, marker='x', color='blue', linewidth=2, linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set(style='darkgrid')
plt.title('close value in d3 vs. Close value in d4', fontsize = 15)
plt.xlabel('Dates' )
plt.ylabel(' scaled close value')


plt.plot( 'Date', 'scaled_close', data=d3, marker='o', color='olive', linewidth=2)
plt.plot( 'Date', 'scaled_close', data=d4, marker='x', color='blue', linewidth=2, linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set(style='darkgrid')
plt.title('close value in d5 vs. Close value in d6', fontsize = 15)
plt.xlabel('Dates' )
plt.ylabel(' scaled close value')


plt.plot( 'Date', 'scaled_close', data=d5, marker='o', color='olive', linewidth=2)
plt.plot( 'Date', 'scaled_close', data=d6, marker='x', color='blue', linewidth=2, linestyle='dashed')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set(style='darkgrid')
plt.title('close value in d7 vs. Close value in d8', fontsize = 15)
plt.xlabel('Dates' )
plt.ylabel(' scaled close value')


plt.plot( 'Date', 'scaled_close', data=d7, marker='o', color='olive', linewidth=2)
plt.plot( 'Date', 'scaled_close', data=d8, marker='x', color='blue', linewidth=2, linestyle='dashed')
plt.legend()
plt.show()

# %%
dataset = pd.read_csv("DFS.csv")
X = dataset.iloc[:, [2,3]].values
Y = dataset.iloc[:, 4].values

# %%
# Split dataset into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)
#cross validation.

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### SVM

# %%
# Fitting SVM to Training set
from sklearn.svm import SVR
regressor = SVR(kernel='linear')
regressor.fit(X_train, Y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting train and test set results
y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)

# %%
# R Square
from sklearn.metrics import r2_score
print('R^2 train: %.3f, test: %.3f' %(r2_score(Y_train, y_train_pred),r2_score(Y_test, y_test_pred)))
# Out:
# R^2 train: 0.998, test: 0.998

# %%
# Mean Squared Error.
from sklearn.metrics import mean_squared_error
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(Y_train, y_train_pred), mean_squared_error(Y_test, y_test_pred)))
# Out:
# MSE train: 0.283, test: 0.325

# %%
# Mean Absolute Error.
from sklearn.metrics import mean_absolute_error
print('MAE train: %.3f, test: %.3f' % (mean_absolute_error(Y_train, y_train_pred), mean_absolute_error(Y_test, y_test_pred)))
# Out:
# MAE train: 0.376, test: 0.392

# %%
# Results are shown in the below plot.

plt.scatter(X_test[:,1], Y_test, color = 'red')
plt.plot(X_test[:,1], y_test_pred, color = 'blue')
plt.title('Regression Results')
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# Fitting Linear Regression to Training set

from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predicting train and test set results
y_train_pred_lr = slr.predict(X_train)
y_test_pred_lr = slr.predict(X_test)

# %%
# R Square
from sklearn.metrics import r2_score
print('R^2 train: %.3f, test: %.3f' %(r2_score(Y_train, y_train_pred_lr),r2_score(Y_test, y_test_pred_lr)))
# Out:
# R^2 train: 0.998, test: 0.998

# %%
# Mean Square Error.
from sklearn.metrics import mean_squared_error
print('MSE train: %.3f, test: %.3f' % (mean_squared_error(Y_train, y_train_pred_lr), mean_squared_error(Y_test, y_test_pred_lr)))
# Out:
# MSE train: 0.279, test: 0.331

# %%
# Mean Absolute Error.
from sklearn.metrics import mean_absolute_error
print('MAE train: %.3f, test: %.3f' % (mean_absolute_error(Y_train, y_train_pred_lr), mean_absolute_error(Y_test, y_test_pred_lr)))
# Out:
# MAE train: 0.378, test: 0.395

# %% [markdown]
# ### LSTM

# %%
# Check the shape of source dataset and prepare input for the LSTM model.

dataset.shape
# Out:
# (1259, 7)

# %%
#Split the data into training and test datasets.

df_train = dataset[dataset['Date'] < '2020-01-01']
df_test = dataset[dataset['Date'] >= '2020-01-01']

# %%
# Check the shape of training dataset.

df_train.shape
# Out:
# (1130, 7)

# %%
# Check the shape of test dataset.

df_test.shape
# Out:
# (129, 7)

# %%
# Prepare the input by selecting 'Open' column that we use in our modeling.

training_set = df_train.iloc[:, 1:2].values

# %%
training_set.shape
# Out:
# (1130, 1)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set_scaled.shape
# Out:
# (1130, 1)

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train.shape
# Out:
# (1070, 60)

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
X_train.shape
# Out:
# (1070, 60, 1)

# %%
y_train.shape
# Out:
# (1070,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.layers import Dropout

regression= Sequential()

#First Input layer and LSTM layer with 0.2% dropout
regression.add(LSTM(units=50,return_sequences=True,kernel_initializer='glorot_uniform',input_shape=(X_train.shape[1],1)))
regression.add(Dropout(0.2))

# Where:
#     return_sequences: Boolean. Whether to return the last output in the output sequence, or the full sequence.

# Second LSTM layer with 0.2% dropout
regression.add(LSTM(units=50,kernel_initializer='glorot_uniform',return_sequences=True))
regression.add(Dropout(0.2))

#Third LSTM layer with 0.2% dropout
regression.add(LSTM(units=50,kernel_initializer='glorot_uniform',return_sequences=True))
regression.add(Dropout(0.2))

#Fourth LSTM layer with 0.2% dropout, we wont use return sequence true in last layers as we dont want to previous output
regression.add(LSTM(units=50,kernel_initializer='glorot_uniform'))
regression.add(Dropout(0.2))
#Output layer , we wont pass any activation as its continous value model
regression.add(Dense(units=1))

#Compiling the network
regression.compile(optimizer='adam',loss='mean_squared_error')


#fitting the network
history = regression.fit(X_train,y_train,batch_size=30,epochs=100)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 16ms/step - loss: 0.0441
# Epoch 2/100
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0107
# Epoch 3/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 4/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0068
# Epoch 5/100
# 36/36 [==============================] - 1s 14ms/step - loss: 0.0064
# Epoch 6/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 7/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0060
# Epoch 8/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 9/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 10/100
# 36/36 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 11/100
# 36/36 [==============================] - 0s 14ms/step - loss: 0.0050
# Epoch 12/100
# ...

# %%
regression.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                20200
# ...

# %%
# Making the predictions and visualising the results

# Getting the real stock price of test data
real_stock_price = df_test.iloc[:, 1:2].values

# %%
# Getting the predicted stock price of test data.
dataset_total = pd.concat((df_train['Open'], df_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(df_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, len(inputs)):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regression.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Visualising the results
plt.figure(figsize=(10,8))
plt.plot(real_stock_price, color = 'red', label = 'Real Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Stock Price')
plt.title('Real vs Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
hist = history.history
fig = plt.figure(figsize=(8, 5))
plt.plot(hist['loss'], lw=3)
plt.title('Training loss', size=15)
plt.xlabel('Epoch', size=15)
plt.tick_params(axis='both', which='major', labelsize=15)

# %%
# R Square
from sklearn.metrics import r2_score
print('R^2 : %.3f' %(r2_score(real_stock_price, predicted_stock_price)))
# Out:
# R^2 : 0.941

# %%
# MSE
from sklearn.metrics import mean_squared_error
print('MSE train: %.3f' % (mean_squared_error(real_stock_price, predicted_stock_price)))
# Out:
# MSE train: 18.464

# %%
# MAE
from sklearn.metrics import mean_absolute_error
print('MAE train: %.3f' % (mean_absolute_error(real_stock_price, predicted_stock_price)))
# Out:
# MAE train: 3.053
